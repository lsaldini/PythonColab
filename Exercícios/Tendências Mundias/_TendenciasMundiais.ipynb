# %% [markdown]
# # Tendências Mundiais

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-bright')
import seaborn as sns

# %%
df = pd.read_csv('TendenciasMundiais.csv')
df.head()
# Out:
#   CountryCode           CountryName  ... FertilityRate.2013  LifeExp.2013
# 0         ABW                 Aruba  ...              1.669     75.328659
# 1         AFG           Afghanistan  ...              5.050     60.028268
# 2         AGO                Angola  ...              6.165     51.866171
# 3         ALB               Albania  ...              1.771     77.537244
# 4         ARE  United Arab Emirates  ...              1.801     77.195634
#
# [5 rows x 7 columns]

# %%
df.shape
# Out:
# (187, 7)

# %%
df.describe()
# Out:
#        FertilityRate.1960  LifeExp.1960  FertilityRate.2013  LifeExp.2013
# count          187.000000    187.000000          187.000000    187.000000
# mean             5.537112     53.734112            2.845543     70.763808
# std              1.717305     12.182463            1.428171      8.590893
# min              1.940000     28.211610            1.124000     48.937927
# 25%              4.311500     43.474451            1.770500     64.517354
# 50%              6.210000     54.699317            2.335000     73.250390
# 75%              6.806500     64.048244            3.790000     76.838622
# max              8.187000     73.549756            7.623000     83.831707

# %%
# gráfico de dispersão 
plt.figure(figsize=(11,7))
plt.scatter(x='FertilityRate.1960', y='LifeExp.1960', data=df, label='1960')
plt.scatter(x='FertilityRate.2013', y='LifeExp.2013', data=df, label='2013')
plt.legend()
plt.title('Fertilidade vs Expectativa de Vida')
plt.xlabel('Fertilidade')
plt.ylabel('Expectativa de Vida')
plt.show()

# %%
# gráfico de dispersão 
plt.figure(figsize=(20,15))
plt.scatter(x='FertilityRate.1960', y='LifeExp.1960', data=df, label='1960')
plt.scatter(x='FertilityRate.2013', y='LifeExp.2013', data=df, label='2013')
plt.legend()
plt.title('Fertilidade vs Expectativa de Vida')
plt.xlabel('Fertilidade')
plt.ylabel('Expectativa de Vida')

#colocar os códigos dos países
for i, cc in enumerate(df['CountryCode']):
  plt.annotate(cc, (df['FertilityRate.1960'][i], df['LifeExp.1960'][i]))
  plt.annotate(cc, (df['FertilityRate.2013'][i], df['LifeExp.2013'][i]))
plt.show()

# %%
df.Region.unique()
# Out:
# array(['The Americas', 'Asia', 'Africa', 'Europe', 'Middle East',
#        'Oceania'], dtype=object)

# %%
df.Region.value_counts()
# Out:
# Africa          53
# Europe          40
# The Americas    36
# Asia            33
# Oceania         13
# Middle East     12
# Name: Region, dtype: int64

# %%
counts = df.Region.value_counts(sort=False)
counts

# %%
# graficos de barras
plt.bar(x=counts.index, height=df.Region.value_counts(sort=False), color=['black', 'red', 'blue', 'orange', 'yellow', 'green'] )
plt.ylabel('Quantidade de países')
plt.xticks(rotation='vertical')
plt.xticks(rotation=45)
plt.show()

# %%
# o mesmo grafico
sns.countplot(data=df, x='Region')
plt.title('Quantidade de registros por região')
plt.show()

# %%
chart = sns.countplot(x='Region', data=df);
chart.set_xticklabels(chart.get_xticklabels(), rotation=45); #rotacionar o labels

# %%
#histograma
plt.hist(df['FertilityRate.1960'], bins=50, alpha=0.5)
plt.hist(df['FertilityRate.2013'], bins=50, alpha=0.5)
plt.ylabel('Taxa')
plt.legend(['1960', '2013']);

# %%
# boxplot
plt.boxplot([df['LifeExp.1960'], df['LifeExp.2013']], labels=['1960', '2013'], showmeans=True)
plt.ylabel('Expectativa de Vida')
plt.show()

# %%
# direto do dataframe. todas as colunas numéricas
df.boxplot();

# %%
# seaborn todos as colunas numéricas
chart = sns.boxplot(data=df)
chart.set_title('Boxplots')
chart.set_ylabel('taxa');

# %%
# só para fertilidade
chart = sns.boxplot(data=df[['FertilityRate.1960','FertilityRate.2013']])
chart.set_title('Boxplots')
chart.set_ylabel('taxa');

# %%
chart = sns.boxplot(data=df[['LifeExp.1960','LifeExp.2013']])
chart.set_title('Boxplots')
chart.set_ylabel('taxa');

# %%
#violin plot
violin = plt.violinplot([df['LifeExp.1960'],df['LifeExp.2013']], showmeans=True);
violin['bodies'][0].set_facecolor('red')
plt.legend(['1960', '2013'], loc='lower right');

# %%
# o mesmo com seaborn
chart = sns.violinplot(data=df[['LifeExp.1960','LifeExp.2013']]);
chart.set_title('Boxplots')
chart.set_ylabel('idade');

# %%
#correlação
correlacao = df.corr()
correlacao
# Out:
#                     FertilityRate.1960  ...  LifeExp.2013
# FertilityRate.1960            1.000000  ...     -0.516687
# LifeExp.1960                 -0.731723  ...      0.797042
# FertilityRate.2013            0.554141  ...     -0.836897
# LifeExp.2013                 -0.516687  ...      1.000000
#
# [4 rows x 4 columns]

# %%
sns.heatmap(correlacao, vmin=-1, vmax=1, cmap=sns.diverging_palette(0,200, n=100));

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_707bb36c_f7a1_11ea_869f_0242ac1c0002row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_707bb36c_f7a1_11ea_869f_0242ac1c0002row0_col1 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_707bb36c_f7a1_11ea_869f_0242ac1c0002row0_col2 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_707bb36c_f7a1_11ea_869f_0242ac1c0002row0_col3 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_707bb36c_f7a1_11ea_869f_0242ac1c0002row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_707bb36c_f7a1_11ea_869f_0242ac1c0002row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_707bb36c_f7a1_11ea_869f_0242ac1c0002row1_col2 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_707bb36c_f7a1_11ea_869f_0242ac1c0002row1_col3 {
#             background-color:  #d95847;
#             color:  #000000;
#         }    #T_707bb36c_f7a1_11ea_869f_0242ac1c0002row2_col0 {
#             background-color:  #f59c7d;
#             color:  #000000;
#         }    #T_707bb36c_f7a1_11ea_869f_0242ac1c0002row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_707bb36c_f7a1_11ea_869f_0242ac1c0002row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_707bb36c_f7a1_11ea_869f_0242ac1c0002row2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_707bb36c_f7a1_11ea_869f_0242ac1c0002row3_col0 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_707bb36c_f7a1_11ea_869f_0242ac1c0002row3_col1 {
#             background-color:  #da5a49;
#             color:  #000000;
#         }    #T_707bb36c_f7a1_11ea_869f_0242ac1c0002row3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_707bb36c_f7a1_11ea_869f_0242ac1c0002row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_707bb36c_f7a1_11ea_869f_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >FertilityRate.1960</th>        <th class="col_heading level0 col1" >LifeExp.1960</th>        <th class="col_heading level0 col2" >FertilityRate.2013</th>        <th class="col_heading level0 col3" >LifeExp.2013</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_707bb36c_f7a1_11ea_869f_0242ac1c0002level0_row0" class="row_heading level0 row0" >FertilityRate.1960</th>
#                         <td id="T_707bb36c_f7a1_11ea_869f_0242ac1c0002row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_707bb36c_f7a1_11ea_869f_0242ac1c0002row0_col1" class="data row0 col1" >-0.731723</td>
#                         <td id="T_707bb36c_f7a1_11ea_869f_0242ac1c0002row0_col2" class="data row0 col2" >0.554141</td>
#                         <td id="T_707bb36c_f7a1_11ea_869f_0242ac1c0002row0_col3" class="data row0 col3" >-0.516687</td>
#             </tr>
#             <tr>
#                         <th id="T_707bb36c_f7a1_11ea_869f_0242ac1c0002level0_row1" class="row_heading level0 row1" >LifeExp.1960</th>
#                         <td id="T_707bb36c_f7a1_11ea_869f_0242ac1c0002row1_col0" class="data row1 col0" >-0.731723</td>
#                         <td id="T_707bb36c_f7a1_11ea_869f_0242ac1c0002row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_707bb36c_f7a1_11ea_869f_0242ac1c0002row1_col2" class="data row1 col2" >-0.787129</td>
#                         <td id="T_707bb36c_f7a1_11ea_869f_0242ac1c0002row1_col3" class="data row1 col3" >0.797042</td>
#             </tr>
#             <tr>
#                         <th id="T_707bb36c_f7a1_11ea_869f_0242ac1c0002level0_row2" class="row_heading level0 row2" >FertilityRate.2013</th>
#                         <td id="T_707bb36c_f7a1_11ea_869f_0242ac1c0002row2_col0" class="data row2 col0" >0.554141</td>
#                         <td id="T_707bb36c_f7a1_11ea_869f_0242ac1c0002row2_col1" class="data row2 col1" >-0.787129</td>
#                         <td id="T_707bb36c_f7a1_11ea_869f_0242ac1c0002row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_707bb36c_f7a1_11ea_869f_0242ac1c0002row2_col3" class="data row2 col3" >-0.836897</td>
#             </tr>
#             <tr>
#                         <th id="T_707bb36c_f7a1_11ea_869f_0242ac1c0002level0_row3" class="row_heading level0 row3" >LifeExp.2013</th>
#                         <td id="T_707bb36c_f7a1_11ea_869f_0242ac1c0002row3_col0" class="data row3 col0" >-0.516687</td>
#                         <td id="T_707bb36c_f7a1_11ea_869f_0242ac1c0002row3_col1" class="data row3 col1" >0.797042</td>
#                         <td id="T_707bb36c_f7a1_11ea_869f_0242ac1c0002row3_col2" class="data row3 col2" >-0.836897</td>
#                         <td id="T_707bb36c_f7a1_11ea_869f_0242ac1c0002row3_col3" class="data row3 col3" >1.000000</td>
#             </tr>
#     </tbody></table>
